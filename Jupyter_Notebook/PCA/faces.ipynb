# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import fetch_lfw_people

# %%
faces = fetch_lfw_people()

# %%
faces.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'target_names', 'DESCR'])

# %%
faces.data.shape
# Out:
# (4874, 2914)

# %%
faces.images.shape
# Out:
# (4874, 62, 47)

# %%
random_indexes = np.random.permutation(len(faces.data))
x = faces.data[random_indexes]

# %%
example_faces = x[:36,:]

# %%
example_faces.shape
# Out:
# (36, 2914)

# %%
def plot_faces(faces):
    fig, axes = plt.subplots(6,6,figsize=(10,10),
                             subplot_kw={'xticks':[], 'yticks':[]},
                             gridspec_kw=dict(hspace=0.1,wspace=0.1))
    for i, ax in enumerate(axes.flat):
        ax.imshow(faces[i].reshape(62,47), cmap='bone')
    plt.show()

# %%
plot_faces(example_faces)

# %%
faces.target_names
# Out:
# array(['Aaron Sorkin', 'Abbas Kiarostami', 'Abdel Nasser Assidi',
#        'Abdul Rahman', 'Abdullah', 'Abdullah Ahmad Badawi',
#        'Abdullah al-Attiyah', 'Adoor Gopalakarishnan', 'Afton Smith',
#        'Ahmad Masood', 'Ahmed Ghazi', 'Ahmed Qureia', 'Aicha El Ouafi',
#        'Aitor Gonzalez', 'Akbar Hashemi Rafsanjani', 'Al Gore',
#        'Alan Ball', 'Alan Greenspan', 'Alan Greer', 'Alan Stonecipher',
#        'Albert Costa', 'Alec Baldwin', 'Alejandro Gonzalez Inarritu',
#        'Alejandro Toledo', 'Alessandro Nesta', 'Alex Barros', 'Alex King',
#        'Alex Penelas', 'Alex Sink', 'Alexandra Pelosi',
#        'Alexis Dennisoff', 'Ali Ahmeti', 'Ali Naimi', 'Alina Kabaeva',
#        'Aline Chretien', 'Alison Krauss', 'Alison Lohman',
#        'Allison Janney', 'Allison Searing', 'Alma Powell', 'Alvaro Uribe',
#        'Alyson Hannigan', 'Amanda Plumer', 'Amelie Mauresmo',
#        'Amer al-Saadi', 'Amy Brenneman', 'Ana Palacio', 'Anders Ebbeson',
#        'Anders Fogh Rasmussen', 'Andre Agassi', 'Andrea De Cruz',
#        'Andrei Konchalovsky', 'Andrew Cuomo', 'Andy Griggs', 'Andy Perez',
#        'Andy Roddick', 'Angela Merkel', 'Anjum Hussain', 'Ann Veneman',
#        'Anna Jones', 'Anna Kournikova', 'Anthony Hazen',
#        'Anthony LaPaglia', 'Anthony Mazur', 'Anton Balasingham',
#        'Ari Fleischer', 'Ariel Sharon', 'Arminio Fraga', 'Arnaud Clement',
#        'Arnoldo Aleman', 'Arsinee Khanjian', 'Art Cooper', 'Art Lopez',
#        'Asa Hutchinson', 'Asif Ali Zardari', 'Atal Bihari Vajpayee',
#        'Audrey Sauret', 'Augusto Pinochet', 'Barbra Streisand',
#        'Barry Nakell', 'Begum Khaleda Zia', 'Benito Santiago',
#        'Benjamin Netanyahu', 'Bertie Ahern', 'Bijan Namdar Zangeneh',
#        'Bill Clinton', 'Bill Curry', 'Bill McBride', 'Bill Simon',
#        'Bill Sizemore', 'Bison Dele', 'Blythe Danner', 'Bob Beauprez',
#        'Bob Geldof', 'Bob Goldman', 'Bob Graham', 'Bob Hayes',
#        'Bob Huggins', 'Bono', 'Boris Becker', 'Boris Trajkovski',
#        'Brad Garrett', 'Brandon Robinson', 'Branko Crvenkovski',
#        'Brenda van Dam', 'Brendan Fraser', 'Brian Cashman',
#        'Brian De Palma', 'Brian Jordan', 'Brian Williams', 'Brooke Adams',
#        'Brooke Shields', 'Buck Rodgers', 'Bulent Ecevit',
#        'Bustam A Zedan Aljanabi', 'Buzz Hargrove', 'Cabas',
#        'Calista Flockhart', 'Camille Lewis', 'Carla Moreno',
#        'Carla Myers', 'Carla Sullivan', 'Carlo Ancelotti',
#        'Carlos Arroyo', 'Carlos Beltran', 'Carlos Vives', 'Carson Daly',
#        'Casey Crowder', 'Casy Preslar', 'Catherine Bell', 'Cathy Freeman',
#        'Cecilia Chang', 'Cedric Benson', 'Chakib Khelil', 'Chan Choi',
#        'Chang Jae On', 'Chang Tso', 'Charla Moye', 'Charles Pouty',
#        'Charlie Williams', 'Charlie Zaa', 'Charlton Heston',
#        'Chen Shui-bian', 'Cherie Blair', 'Cheryl Hines', 'Chhouk Rin',
#        'Chin-Feng Chen', 'Chris Dodd', 'Chris Gratton', 'Chris Reitsma',
#        'Chris Tucker', 'Christian Patino', 'Christina Sawaya',
#        'Christine Todd Whitman', 'Christopher Reeve', 'Chung Mong-joon',
#        'Cindy Taylor', 'Ciro Gomes', 'Clare Latimer', 'Clint Howard',
#        'Colin Campbell', 'Colin Farrell', 'Colin Montgomerie',
#        'Colin Powell', 'Conan OBrien', 'Condoleezza Rice',
#        'Connie Freydell', 'Curtis Strange', 'Damon Dash', 'Damon van Dam',
#        'Dan Reeves', 'Daniel Pearl', 'Daniel Rouse', 'Daniel Zelman',
#        'Daniela Cicarelli', 'Daniela Hantuchova', 'Danny Avalon',
#        'Darin Erstad', 'Darren Clarke', 'Dave Johnson', 'Dave Matthews',
#        'David Beckham', 'David Brent', 'David Caruso', 'David Chase',
#        'David Coulthard', 'David Leahy', 'David McCullough',
#        'David Myers', 'David Nalbandian', 'David Trimble',
#        'David Westerfield', 'David Wolf', 'Dawn Staley',
#        'Debbie Reynolds', 'Debra Brown', 'Debra Messing', 'Deepa Mehta',
#        'Demetrius Ferraciu', 'Denis Fassou-Nguesso', 'Derek King',
#        'Derrick Battie', 'Dick Armey', 'Dick Cheney', 'Dick Clark',
#        'Dick Vermeil', 'Diego Armando Maradona', 'Din Samsudin',
#        'Dino Risi', 'Dionigi Tettamanzi', 'Don Lake', 'Don Siegelman',
#        'Donald Rumsfeld', 'Doris Roberts', 'Doris Schroeder',
#        'Doug Collins', 'Doug Melvin', 'Doug Racine', 'Drew Bledsoe',
#        'Drew Gooden', 'Dustin Hoffman', 'Earl Counter', 'Ed Book',
#        'Ed Mekertichian', 'Edmund Stoiber', 'Eduard Shevardnadze',
#        'Edward James Olmos', 'Edward Johnson', 'Edward Kennedy',
#        'Edward Norton', 'Edward Said', 'Eli Rosenbaum', 'Eliane Karp',
#        'Elin Nordegren', 'Elisabeth Schumacher', 'Elizabeth Berkeley',
#        'Elizabeth Shue', 'Elizabeth Taylor', 'Ellen Barkin',
#        'Ellen DeGeneres', 'Ellen Martin', 'Ellen Saracini',
#        'Elliott Mincberg', 'Elsa Zylberstein', 'Emmanuel Milingo',
#        'Emmanuelle Jagodsinski', 'Enrica Fico', 'Enrique Bolanos',
#        'Eric Daze', 'Erika Christensen', 'Erika Harold', 'Erin Runnion',
#        'Ernie Harwell', 'Ester Canadas', 'Eugene Teslovic', 'Eve Ensler',
#        'Evelyn Lauder', 'Fabricio Oberto', 'Federico Trillo',
#        'Felipe Perez Roque', 'Felix Sanchez', 'Fernando Gonzalez',
#        'Fernando Henrique Cardoso', 'Fernando Leon de Aranoa',
#        'Fernando Vargas', 'Fidel Castro', 'Fran Drescher', 'Frank Bell',
#        'Frank Dunham Jr', 'Frank Keating', 'Frank Taylor',
#        'Franz Muentefering', 'Fred Huff', 'Fred Rogers', 'Fred Thompson',
#        'Fredric Seaman', 'GL Peiris', 'Gabi Zimmer', 'Gabriel Batistuta',
#        'Gabrielle Rose', 'Garry Kasparov', 'Gary Sinise', 'Gary Winnick',
#        'Gene Sauers', 'Geoffrey Rush', 'George Clooney',
#        'George Galloway', 'George HW Bush', 'George Harrison',
#        'George Karl', 'George Papandreou', 'George Pataki',
#        'George Robertson', 'George W Bush', 'Georgi Parvanov',
#        'Georgina Papin', 'Gerhard Schroeder', 'Gerry Adams', 'Gian Marco',
#        'Giannina Facio', 'Gideon Black', 'Gilles Panizzi',
#        'Gisele Bundchen', 'Gloria Macapagal Arroyo', 'Gloria Trevi',
#        'Goldie Hawn', 'Goran Persson', 'Gordon Brown', 'Gordon Lightfoot',
#        'Grant Rossenmeyer', 'Gray Davis', 'Greg Hodge',
#        'Guido Westerwelle', 'Guillermo Ortiz', 'Gunilla Backman',
#        'Gustavo Kuerten', 'Gwyneth Paltrow', 'Habib Hisham', 'Hal Sutton',
#        'Hamid Karzai', 'Hana Urushima', 'Hans Blix', 'Harald Ringstorff',
#        'Harriet Lessy', 'Harrison Ford', 'Hassan Nasrallah',
#        'Hassan Wirajuda', 'Hatsui Hasuike', 'Heath Ledger',
#        'Heather Mills', 'Heather Whitestone McCallum',
#        'Hedayat Amin Arsala', 'Heidi Klum', 'Hernan Crespo',
#        'Herta Daeubler-Gmelin', 'Hillary Clinton', 'Hitoshi Tanaka',
#        'Horace Donovan Reid', 'Horace Newcomb',
#        'Horacio de Jesus Montoya', 'Horst Koehler', 'Hu Jintao',
#        'Hugo Chavez', 'Hussein Malik', 'Ian Thorpe', 'Ian Wilmut',
#        'Igor Ivanov', 'Ilie Nastase', 'Imran Khan', 'Intisar Ajouri',
#        'Ira Einhorn', 'Irfan Ahmed', 'Irwan Fadzi Idris',
#        'Ishaq Shahryar', 'JK Rowling', 'Jaap de Hoop Scheffer',
#        'Jack LaLanne', 'Jack Straw', 'Jack Welch', 'Jackie Chan',
#        'Jacques Chirac', 'Jade Jagger', 'Jake Gyllenhaal', 'James Franco',
#        'James Gandolfini', 'James Harris', 'James Kelly',
#        'James McGreevey', 'James Wolfensohn', 'Jan Bjoerklund',
#        'Jan-Michael Gambill', 'Jane Clayson', 'Jane Fonda',
#        'Jane Menelaus', 'Jane Walker Wood', 'Jawad Boulus', 'Jay Leno',
#        'Jayson Williams', 'Jean Chretien', 'Jean Nagel',
#        'Jean-Claude Braquet', 'Jean-Francois Pontal',
#        'Jean-Pierre Raffarin', 'Jeanne Anne Schroeder', 'Jeb Bush',
#        'Jeff Feldman', 'Jeffrey Donaldson', 'Jeffrey Immelt',
#        'Jennifer Aniston', 'Jennifer Capriati', 'Jennifer Furminger',
#        'Jennifer Garner', 'Jennifer Lopez', 'Jerry Lewis', 'Jerry Rice',
#        'Jerry Seinfeld', 'Jesse Helms', 'Jesus Cardenal', 'Jim Doyle',
#        'Jim Spinoza', 'Jimmy Szymanski', 'Joe Plumeri', 'Joe Torre',
#        'Joerg Haider', 'John Ashcroft', 'John Bolton', 'John Burnett',
#        'John Franco', 'John Geoghan', 'John Howard', 'John Kerr',
#        'John Malkovich', 'John Manley', 'John McCain', 'John Perrota',
#        'John Philip Elkann', 'John Prescott', 'John Spencer',
#        'John Travolta', 'John Warner', 'John Wayne', 'Johnny Carson',
#        'Johnny Hallyday', 'Johnny Tapia', 'Johnny Unitas', 'Jon Corzine',
#        'Jorge Alberto Galindo', 'Jorge Moreno', 'Joschka Fischer',
#        'Jose Acasuso', 'Jose Serra', 'Jose Theodore', 'Joseph Biden',
#        'Joseph Deiss', 'Joseph Kabila', 'Juan Antonio Samaranch',
#        'Juan Carlos Ferrero', 'Juan Ignacio Chela', 'Juan Pablo Montoya',
#        'Juan Sanchez', 'Judi Patton', 'Julia Tymoshenko',
#        'Julianne Moore', 'Julio Cesar Chavez', 'Juljia Vysotskij',
#        'Junichiro Koizumi', 'Justin Guarini', 'Justin Leonard',
#        'Justin Timberlake', 'Justine Pasek', 'Karen Lynn Gorney',
#        'Karen Pereiras', 'Karin Pilsaeter', 'Karin Stoiber',
#        'Kaspar Villiger', 'Kate Capshaw', 'Kate Hudson', 'Kate Winslet',
#        'Katherine Harris', 'Kathie Louise Saunders', 'Kathryn Bigelow',
#        'Katie Harman', 'Katrin Cartlidge', 'Kay Bailey Hutchison',
#        'Keith Snyder', 'Kelly Clarkson', 'Kelly Ripa', 'Ken Balk',
#        'Kevin Garnett', 'Kevin Sorbo', 'Khalid Qazi',
#        'Khum Bahadur Khadka', 'Kifah Ajouri', 'Kim Dae-jung',
#        'Kimi Raikkonen', 'Kjell Magne Bondevik', 'Kofi Annan',
#        'Kristen Breitweiser', 'Kristin Davis', 'Kristin Scott Thomas',
#        'Kurt Russell', 'Kurt Warner', 'Lance Armstrong', 'Lance Bass',
#        'Larry Brown', 'Larry Ellison', 'Larry Greene', 'Larry Wilmore',
#        'Laura Bozzo', 'Laura Bush', 'Laura Linney', 'Laura Morante',
#        'Laura Ziskin', 'Laurie Laychak', 'Lee Ann Womack',
#        'Lee Chang-dong', 'Lee Tae-sik', 'Lennox Lewis', 'Lenny Kravitz',
#        'Lesley McCulloch', 'Lew Rywin', 'Li Peng', 'Liam Neeson',
#        'Liliana Cavani', 'Lindsay Davenport', 'Lindy Ruff',
#        'Lisa Gottsegen', 'Liu Mingkang', 'Liu Xiaoqing', 'Liza Minnelli',
#        'Lleyton Hewitt', 'Lori Berenson', 'Luca Cordero di Montezemolo',
#        'Luciano Pavarotti', 'Lucio Angulo', 'Lucy Liu', 'Lynne Cheney',
#        'Madeleine Albright', 'Madeleine Webber', 'Maggie Cheung',
#        'Maha Habib', 'Mahathir Mohamad', 'Malak Habbak', 'Mamdouh Habib',
#        'Manijeh Hekmat', 'Marat Safin', 'Marc Grossman',
#        'Marcella Anderson', 'Marco Antonio Barrera', 'Marco Irizarry',
#        'Margaret Caruso', 'Maria Conchita Alonso', 'Maria Wetterstrand',
#        'Mariana Pollack', 'Mark Foley', 'Mark Heller', 'Mark Kelly',
#        'Mark Komara', 'Mark Mulder', 'Mark Polansky', 'Mark Richt',
#        'Mark Swartz', 'Martha Stewart', 'Martin Boryczewski',
#        'Martin Sheen', 'Martina Hingis', 'Marty Mornhinweg',
#        'Mary Catherine Correll', 'Mary Maddux', 'Masao Azuma',
#        'Mathias Reichhold', 'Matt Damon', 'Matt Dillon', 'Matt Herden',
#        'Maurice Papon', 'Megawati Sukarnoputri', 'Mel Gibson',
#        'Mesut Yilmaz', 'Michael Bloomberg', 'Michael Chang',
#        'Michael Chiklis', 'Michael Douglas', 'Michael Munoz',
#        'Michael Patrick King', 'Michael Schumacher',
#        'Michael Smith Foster', 'Michel Therrien',
#        'Michelangelo Antonioni', 'Michele Placido', 'Michelle Bachelet',
#        'Michelle Pfeiffer', 'Miguel Cotto', 'Miguel Estrada',
#        'Mike Fisher', 'Mike Matthews', 'Mike Miller', 'Mike Samp',
#        'Mike Tice', 'Mike Tyson', 'Mike Webster', 'Miles Stewart',
#        'Milt Palacio', 'Milton Berle', 'Minnie Driver',
#        'Mireya Elisa Moscoso Rodriguez', 'Miroljub', 'Misty Dawn Clymer',
#        'Mo Elleithee', 'Moby', 'Mohammad Aktar', 'Mohammad Khatami',
#        'Mohammed Ashraf Hafiz', 'Momcilo Perisic', 'Monica Bellucci',
#        'Monica Gabrielle', 'Monica Seles', 'Moon-So-ri', 'Ms Dynamite',
#        'Mstislav Rostropovich', 'Myung Yang', 'Nadine Vinzens',
#        'Naji Sabri', 'Nancy Greenlaw', 'Nancy Kerrigan', 'Nancy Reagan',
#        'Nanni Moretti', 'Naomi Campbell', 'Natalie Cole',
#        'Natasha Henstridge', 'Nate Hybl', 'Nebojsa Pavkovic',
#        'Nelson Mandela', 'Nia Vardalos', 'Nick Nolte', 'Nick Rahall',
#        'Nick Rimando', 'Nicolas Escude', 'Nicolas Kiefer',
#        'Nicolas Latorre', 'Nicole', 'Nicole Kidman', 'Nicole Parker',
#        'Nikki McKibbin', 'Noelle Bush', 'Norman Mailer', 'Nur Jaafar',
#        'Oleksandr Moroz', 'Olivera Labus', 'Olivia Newton-John',
#        'Oprah Winfrey', 'Oracene Williams', 'Orrin Hatch',
#        'Oxana Fedorova', 'Pamela Anderson', 'Pamela Melroy',
#        'Pat Rochester', 'Patricia Clarkson', 'Patricia Garone',
#        'Patricia Johnson', 'Patricia Phillips', 'Patricia Russo',
#        'Patrick Ewing', 'Patrick Leahy', 'Patty Duke', 'Patty Sheehan',
#        'Paul Brandt', 'Paul Johnson', 'Paul Li Calsi', 'Paul Lo Duca',
#        'Paul Martin', 'Paul McCartney', 'Paul ONeill', 'Paul Patton',
#        'Paul Pierce', 'Paula Abdul', 'Paula Locke',
#        'Paulo Cesar Pinheiro', 'Pedro Alvarez', 'Pedro Malan',
#        'Pedro Martinez', 'Pedro Velasquez', 'Penelope Cruz',
#        'Penelope Taylor', 'Pernilla Bjorn', 'Perri Shaw',
#        'Pervez Musharraf', 'Pete Sampras', 'Peter Ahearn',
#        'Peter Costello', 'Peter Gabriel', 'Peter Gilmour',
#        'Peter Holmberg', 'Peter Mansbridge', 'Peter Mullan',
#        'Peter Struck', 'Petro Symonenko', 'Pham Thi Mai Phuong',
#        'Phil Donahue', 'Phil Gramm', 'Pierce Brosnan', 'Pierre Png',
#        'Prince Charles', 'Prince Harry', 'Prince Willem-Alexander',
#        'Priscilla Owen', 'Priscilla Presley', 'Rachel Griffiths',
#        'Rachel Wadsworth', 'Rahul Dravid', 'Ralph Fiennes',
#        'Ranil Wickremasinghe', 'Raquel Welch', 'Raul Cubas',
#        'Raul Ibanez', 'Ray Price', 'Ray Romano', 'Rebecca Romijn-Stamos',
#        'Rebekah Chantay Revels', 'Reese Witherspoon', 'Ricardo Lagos',
#        'Richard Branson', 'Richard Butler', 'Richard Gephardt',
#        'Richard Hamilton', 'Richard Regenhard', 'Richard Shelby',
#        'Rick Caruso', 'Rick Santorum', 'Ridley Scott', 'Rita Moreno',
#        'Robert Altman', 'Robert Bonner', 'Robert Duvall', 'Robert Evans',
#        'Robert Fico', 'Robert Gordon Card', 'Robert Lee Yates Jr',
#        'Robert Mueller', 'Robert Redford', 'Robert Torricelli',
#        'Robert Vowler', 'Roberto Guaterroma', 'Robin Wright Penn',
#        'Rod Paige', 'Rohman al-Ghozi', 'Rolf Zimmermann',
#        'Roman Polanski', 'Ron Howard', 'Ron Kirk',
#        'Ronaldo Luis Nazario de Lima', 'Rose Linkins', 'Rose Marie',
#        'Roseanne Barr', 'Roy Jones Jr', 'Rubens Barrichello',
#        'Rudolf Schuster', 'Rudolph Giuliani', 'Russell Simmons',
#        'Ruth Dreifuss', 'S Jayakumar', 'Sabah Al-Ahmad Al-Jaber Al-Sabah',
#        'Sadam Hassan', 'Saddam Hussein', 'Sahim Alwan', 'Sam Mendes',
#        'Sam Torrance', 'Samantha Ledster', 'Sandra Ceccarelli',
#        'Scott Ritter', 'Scott Rolen', 'Scott Sullivan', 'Scott Wolf',
#        'Sean Patrick Thomas', 'Sean Penn', 'Sebastian Porto',
#        'Serena Karlan', 'Serena Williams', 'Sergei Ivanov',
#        'Sergio Garcia', 'Sergio Vieira De Mello', 'Shafal Mosed',
#        'Shane Loux', 'Shannon OBrien', 'Shannyn Sossamon', 'Sharon Stone',
#        'Shaun Pollock', 'Sheila Taormina', 'Shimon Peres', 'Sim Yong',
#        'Simon Cowell', 'Slobodan Milosevic', 'Sophia Loren',
#        'Sourav Ganguly', 'Spencer Abraham', 'Stacey Yamaguchi',
#        'Stefan Holm', 'Stefano Accorsi', 'Stefano Gabbana', 'Steffi Graf',
#        'Stephanie Moore', 'Stephanie Zimbalist', 'Stephen Arigbabu',
#        'Stephen Frears', 'Stephen Push', 'Steve Pagliuca', 'Steve Shiver',
#        'Steve Spurrier', 'Steve Wariner', 'Steven Hatfill',
#        'Stockard Channing', 'Suh Young-hoon', 'Sun Myung Moon',
#        'Susan Collins', 'Susan Sarandon', 'Suzanne Torrance',
#        'Svetislav Pesic', 'Syed Ibrahim', 'Sylvester Stallone',
#        'Tab Baldwin', 'Taha Yassin Ramadan', 'Taia Balk',
#        'Takeshi Kitano', 'Tali Imani', 'Talisa Soto', 'Tang Jiaxuan',
#        'Tangra Riggle', 'Tara Dawn Christensen', 'Tariq Aziz',
#        'Tatiana Gratcheva', 'Tayyeb Abdel Rahim', 'Ted Washington',
#        'Terry Bradshaw', 'Terry Gilliam', 'Thabo Mbeki', 'Thalia',
#        'Theodore Tweed Roosevelt', 'Thierry Mariani', 'Thomas Birmingham',
#        'Thomas Bjorn', 'Thomas Cloyd', 'Thomas Franklin',
#        'Thomas Haeggstroem', 'Thomas Klestil', 'Thor Pedersen',
#        'Tian Zhuang Zhuang', 'Tiffany Limos', 'Tiger Woods', 'Tim Jones',
#        'Tina Conner', 'Tina Fey', 'Todd Haynes', 'Tom Brady',
#        'Tom Cruise', 'Tom Daschle', 'Tom Hanks', 'Tom Harkin',
#        'Tom Ridge', 'Tom Welch', 'Tommy Franks', 'Tommy Haas',
#        'Tommy Lasorda', 'Tomoko Hagiwara', 'Tonga', 'Tony Blair',
#        'Tony Cummo', 'Tony Shalhoub', 'Tonya Payne', 'Trent Lott',
#        'Trevor Watson', 'Vaclav Havel', 'Vanessa Redgrave',
#        'Vanessa Williams', 'Venus Williams', 'Viara Vike-Freiberga',
#        'Vicente Fernandez', 'Vicente Fox', 'Viktor Yushchenko',
#        'Vincent Cianci Jr', 'Vinnie Jones', 'Vladimir Meciar',
#        'Vladimir Putin', 'Vojislav Kostunica', 'Vojislav Seselj',
#        'Wan Yanhai', 'Wayne Brady', 'Wendell Bryant', 'Wendy Selig',
#        'Wilbert Elki Meza Majino', 'Will Ofenheusle', 'Will Self',
#        'Will Smith', 'Will Young', 'William Harrison', 'William Hochul',
#        'William Ragland', 'William Rosenberg', 'William Shatner',
#        'Wolfgang Schuessel', 'Wycliffe Grousbeck', 'Xanana Gusmao',
#        'Yao Ming', 'Yasein Taher', 'Yashwant Sinha', 'Yoko Ono',
#        'Yoriko Kawaguchi', 'Zhu Rongji', 'Ziwang Xu', 'Zorica Radovic',
#        'Zulfiqar Ahmed'], dtype='<U32')

# %% [markdown]
# # 特征脸

# %%
from sklearn.decomposition import PCA
pca = PCA(svd_solver='randomized')

# %%
# %time pca.fit(x)
# Out:
# Wall time: 33.4 s
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#     svd_solver='randomized', tol=0.0, whiten=False)

# %%
pca.components_.shape
# Out:
# (2914, 2914)

# %%
plot_faces(pca.components_[:36])

# %%
faces2 = fetch_lfw_people(min_faces_per_person=40)

# %%
faces2.target_names
# Out:
# array(['Ariel Sharon', 'Colin Powell', 'Donald Rumsfeld', 'George W Bush',
#        'Gerhard Schroeder', 'Gloria Macapagal Arroyo', 'Hugo Chavez',
#        'Jacques Chirac', 'Jean Chretien', 'Jennifer Capriati',
#        'John Ashcroft', 'Junichiro Koizumi', 'Laura Bush',
#        'Lleyton Hewitt', 'Serena Williams', 'Tony Blair',
#        'Vladimir Putin'], dtype='<U23')

# %%
faces2.target_names.shape
# Out:
# (17,)
