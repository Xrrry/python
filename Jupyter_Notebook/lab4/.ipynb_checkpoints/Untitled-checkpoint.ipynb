# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.random(50)*10
y
# Out:
# array([2.0549922 , 1.49794084, 2.60465614, 5.69461137, 5.35931563,
#        0.99062938, 6.093241  , 0.0249562 , 6.61583102, 6.94276319,
#        8.51711506, 8.01931888, 5.76530023, 4.68051844, 6.28443366,
#        9.28340892, 5.39823553, 7.93615739, 3.0299299 , 8.54454524,
#        4.79672545, 2.98190618, 3.26344724, 4.47230156, 5.37344418,
#        5.44175631, 8.35299662, 0.82596462, 7.16215341, 9.61255488,
#        8.68724075, 4.46920449, 2.14001084, 5.29482763, 8.66435703,
#        9.90214905, 5.85976802, 0.14477393, 7.21169008, 3.47000117,
#        0.36869625, 0.08818004, 2.33107265, 5.28203814, 4.13026324,
#        3.59172823, 2.28868008, 2.65391285, 0.49846126, 2.39021012])

# %%
y1 = y1.reshape(10,5)
y1
# Out:
# array([[6.28352928, 5.63489956, 6.60051337, 4.71570911, 5.28674946],
#        [2.70095081, 9.92883358, 0.80874793, 2.30033512, 3.36995039],
#        [3.38426254, 2.12024205, 6.9495009 , 0.89455953, 1.82175296],
#        [7.78228053, 0.93361618, 5.47679252, 8.0127159 , 7.68151603],
#        [9.74915075, 7.05601602, 8.2126169 , 1.10509004, 7.17070377],
#        [3.53304656, 2.91931381, 8.58586823, 2.52161979, 8.73069173],
#        [8.96752359, 1.05087975, 1.91401546, 5.75322878, 0.94834707],
#        [3.99596883, 4.45336257, 5.79346106, 3.45029642, 2.87348181],
#        [5.16456715, 7.58343174, 2.29655487, 8.85819966, 7.95566039],
#        [5.39837807, 2.89096516, 4.18035338, 0.82442642, 9.20989075]])

# %%
x = [np.mean(a[:]) for a in y1]
x
# Out:
# [5.704280155898037,
#  3.8217635640744696,
#  3.034063595966857,
#  5.977384231154646,
#  6.658715494284722,
#  5.258108023945365,
#  3.726798932044269,
#  4.113314139535349,
#  6.3716827602628054,
#  4.500802756795105]

# %%
plt.scatter(range(50),y)
plt.plot(range(50),y)
plt.show()

# %%
plt.plot(range(10), x)
plt.show()

# %%
c = ['D','C','B','A']

# %%
d = [c[int((i-min(x))/((max(x)-min(x))/3))] for i in x]
e = [(i-min(x))/((max(x)-min(x))/3) for i in x]
print(d)
print(e)
# Out:
# ['B', 'D', 'D', 'B', 'A', 'C', 'D', 'D', 'B', 'C']
# [2.210046620893757, 0.6519522344806433, 0.0, 2.436085492695503, 3.0, 1.840765257218752, 0.5733532671638601, 0.8932586415285999, 2.7624328552859456, 1.2139696737573074]

# %%
f = (max(x)-min(x))/4
g = [0,0,0,0]
for i in range(4):
    g[i] = i*f+min(x)
g
# Out:
# [3.034063595966857, 3.940226570546323, 4.84638954512579, 5.752552519705256]

# %%
plt.plot(range(10), x)
for i in range(1,4):
    plt.hlines(g[i],0,10)
for i in range(10):
    plt.annotate(d[i],xy=(i,x[i]),fontsize=14)
plt.show()
