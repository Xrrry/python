# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.random(50)*10
y
# Out:
# array([5.68818118e+00, 4.27203845e-02, 7.51338026e+00, 3.26927423e+00,
#        4.10924661e-01, 1.26814882e+00, 8.48467652e+00, 3.42561155e-01,
#        4.79431028e+00, 9.31816732e+00, 6.84089577e+00, 5.62947291e+00,
#        9.87320582e+00, 7.58298080e-03, 7.14353201e+00, 1.32176010e+00,
#        4.59775534e-01, 7.99600466e+00, 9.49066592e+00, 1.32484616e-01,
#        7.36959800e+00, 8.19446103e+00, 8.55231756e+00, 7.13961396e+00,
#        9.88766198e+00, 7.87624154e+00, 3.50847207e+00, 7.29995196e+00,
#        6.70845830e+00, 7.52846033e+00, 1.30481431e+00, 3.97202620e+00,
#        1.48664796e+00, 1.57886796e+00, 4.57102228e+00, 7.99983947e+00,
#        9.93027614e-01, 2.58117773e+00, 7.83411391e+00, 5.55092265e+00,
#        2.40423142e+00, 6.78987442e+00, 4.19461505e-01, 9.02557820e+00,
#        9.88441402e+00, 2.88271209e+00, 5.13199561e+00, 6.50605069e+00,
#        8.85377052e+00, 9.16535860e+00])

# %%
y1 = y.reshape(10,5)
y1
# Out:
# array([[5.68818118e+00, 4.27203845e-02, 7.51338026e+00, 3.26927423e+00,
#         4.10924661e-01],
#        [1.26814882e+00, 8.48467652e+00, 3.42561155e-01, 4.79431028e+00,
#         9.31816732e+00],
#        [6.84089577e+00, 5.62947291e+00, 9.87320582e+00, 7.58298080e-03,
#         7.14353201e+00],
#        [1.32176010e+00, 4.59775534e-01, 7.99600466e+00, 9.49066592e+00,
#         1.32484616e-01],
#        [7.36959800e+00, 8.19446103e+00, 8.55231756e+00, 7.13961396e+00,
#         9.88766198e+00],
#        [7.87624154e+00, 3.50847207e+00, 7.29995196e+00, 6.70845830e+00,
#         7.52846033e+00],
#        [1.30481431e+00, 3.97202620e+00, 1.48664796e+00, 1.57886796e+00,
#         4.57102228e+00],
#        [7.99983947e+00, 9.93027614e-01, 2.58117773e+00, 7.83411391e+00,
#         5.55092265e+00],
#        [2.40423142e+00, 6.78987442e+00, 4.19461505e-01, 9.02557820e+00,
#         9.88441402e+00],
#        [2.88271209e+00, 5.13199561e+00, 6.50605069e+00, 8.85377052e+00,
#         9.16535860e+00]])

# %%
x = [np.mean(a[:]) for a in y1]
x
# Out:
# [3.3848961432772056,
#  4.841572817981988,
#  5.898937895992339,
#  3.8801381655394485,
#  8.228730505505633,
#  6.5843168384256625,
#  2.5826757409015473,
#  4.991816274857425,
#  5.7047119131243536,
#  6.507977502151844]

# %%
plt.scatter(range(50),y)
plt.plot(range(50),y)
plt.show()

# %%
plt.plot(range(10), x)
plt.show()

# %%
c = ['D','C','B','A']

# %%
d = [c[int((i-min(x))/((max(x)-min(x))/3))] for i in x]
e = [(i-min(x))/((max(x)-min(x))/3) for i in x]
print(d)
print(e)
# Out:
# ['D', 'C', 'C', 'D', 'A', 'B', 'D', 'C', 'C', 'B']
# [0.4262553778639686, 1.2002524796120217, 1.7620775709868637, 0.689399489766842, 3.0, 2.1262498847572124, 0.0, 1.28008351020209, 1.6588766682508778, 2.0856874002667674]

# %%
f = (max(x)-min(x))/4
g = [0,0,0,0]
for i in range(4):
    g[i] = i*f+min(x)
g
# Out:
# [2.5826757409015473, 3.9941894320525684, 5.40570312320359, 6.8172168143546115]

# %%
plt.plot(range(10), x)
for i in range(1,4):
    plt.hlines(g[i],0,10)
for i in range(10):
    plt.annotate(d[i],xy=(i,x[i]),fontsize=14)
plt.show()
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# <ipython-input-43-68e908342b15> in <module>
#       3     plt.hlines(g[i],0,10)
#       4 for i in range(10):
# ----> 5     plt.annotate(d[i]+min(x),xy=(i,x[i]),fontsize=14)
#       6 plt.show()
#
# TypeError: can only concatenate str (not "numpy.float64") to str
